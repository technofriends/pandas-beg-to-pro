# %% [markdown]
# ## Scope for Today's Lecture ###
#
# ### Sorting ###
# * Sorting basis a column name.
# * Ascending order and Descending order sorts
# * Sorting by multiple column names
# * How to specify which columns should be picked when for sorting
#
# ### Subsetting ###
#
# * Selecting just one column
# * Selecting several columns basis a list
# * Selecting rows basis a logical condition
# * Selecting based on string values
# * Selecting rows basis multiple conditions

# %%
# load the dataframe
import pandas as pd

df = pd.read_csv('airbnb.csv', index_col="id", low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102599 entries, 1001254 to 6094647
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   NAME                            102349 non-null  object
#  1   host id                         102599 non-null  int64
#  2   host_identity_verified          102310 non-null  object
#  3   host name                       102193 non-null  object
#  4   neighbourhood group             102570 non-null  object
#  5   neighbourhood                   102583 non-null  object
#  6   lat                             102591 non-null  float64
#  7   long                            102591 non-null  float64
#  8   country                         102067 non-null  object
#  9   country code                    102468 non-null  object
#  10  instant_bookable                102494 non-null  object
#  11  cancellation_policy             102523 non-null  object
# ...

# %%
# lets convert the price column to float
df['price'] = df['price'].str.replace('$', '')
df['price'] = df['price'].str.replace(',', '')
df['price'] = df['price'].astype(float)

# %%
# sort basis the price

df[['NAME','host id','price','country']].sort_values(by='price', ascending=False).head(10)
# Out:
#                                                        NAME      host id  \
# id
# 36516435                Great 1BD waterfront City Island NY  83460973881
# 40084846                  Beautiful Central Harlem sleeps 4  79723019119
# 13894780                                         法拉盛中心公寓楼高层  35971606080
# 22458743   Private room (Paris Room) in Bushwick Brownstone  31603093641
# 35580287   One cozy bedroom near Verrazano bridge and ferry  32202051101
# 43808452                   Lovely apartment in Williamsburg  98253797403
# 38934957     Bright Private room, perfect for fashion week!  45276187282
# 30131847  ❤️Couples Retreat/A Road Warriors Dream🌟Perf Loc.   9456551231
# 32763557                             纽约之家(PrivateBathroom4)  26650828572
# 48997311           West 50th Street, Luxury Svcd Studio Apt  60719256293
#
#            price        country
# id
# 36516435  1200.0  United States
# 40084846  1200.0  United States
# 13894780  1200.0  United States
# ...

# %%
df[['NAME','host id','price','service fee','country']].sort_values(by='price', ascending=True).head(10)
# Out:
#                                                        NAME      host id  \
# id
# 14396820  NEWLY Renovated Private 2 Bed Apt on 1 st Floor..  96466051733
# 34820874                     A private humble abode for you   4833155663
# 39127710  Cozy basement with open design, separate entrance  58787926973
# 26159153     Comfortable double room with balcony(舒适双人房带阳台)  82834973843
# 34681142          Charming Greenwich Village Artist’s Haven  71941078154
# 26329814  Pvt studio with pvt entrance&pvt bathroom near...  44535559262
# 48663721       SUNNY APT Best location In Williamsburg!!!!!  13298174979
# 35660370  1 Bed in a 4-Bed Mixed  Dorm with Private Bath...  54281995181
# 7479815                 Gorgeous, Cozy Studio w/ Projector!  40963832458
# 32436043        twin bed in sharing room near Grand Central   3926079443
#
#           price service fee        country
# id
# 14396820   50.0        $10   United States
# 34820874   50.0        $10   United States
# ...

# %%
columns_to_sort_on = ['price', 'minimum nights']
df[['NAME','host id','price','service fee','country','minimum nights']].sort_values(by=columns_to_sort_on, ascending=False).head(10)
# Out:
#                                                      NAME      host id  \
# id
# 36969321  Modern 2 Bed. Apartment - 10 Min. to Manhattan!  82598292916
# 6637005                1BR GARDEN APT 25 MIN TO MANHATTAN  74550051012
# 9991123            Luxurious SOHO 2 BR Washington Sq Park  51005521408
# 10434620         West 50th Street, Luxury Svcd Studio Apt  74492410019
# 11921964         1.5 BATHRM SUNNY SPACIOUS ROOM BY SUBWAY  51256717787
# 19725411                                         Oasis II  59005379313
# 32520545                                       NYCHaven1:  20000330853
# 36516435              Great 1BD waterfront City Island NY  83460973881
# 37737018                         Sun Drenched Dreamy Loft  91778347994
# 37829805  Feel-Good Decor, Lux Private Room Great Loc 4-4  90299456137
#
#            price service fee        country  minimum nights
# id
# 36969321  1200.0       $240   United States            60.0
# ...

# %%
select_columns = ['NAME','host id','price','service fee','country','minimum nights']
columns_to_sort_on = ['price', 'minimum nights']

df[select_columns].sort_values(by=columns_to_sort_on, ascending=[False, True]).head(10)
# Out:
#                                                        NAME      host id  \
# id
# 24444262            Cozy room in bright, spacious apartment  84040511136
# 3877162       Bushwick Room w/ Private Entrance & Bathroom!  45360462434
# 7946509                    Cozy room in Chic Apt Astoria NY  69686754911
# 22458743   Private room (Paris Room) in Bushwick Brownstone  31603093641
# 22765822  Charming 1 bedroom in a 2 bedroom west village...  86456574046
# 30131847  ❤️Couples Retreat/A Road Warriors Dream🌟Perf Loc.   9456551231
# 32763557                             纽约之家(PrivateBathroom4)  26650828572
# 33328007                     Beautiful King Bed Hotel Room!  32959832005
# 35580287   One cozy bedroom near Verrazano bridge and ferry  32202051101
# 35580287   One cozy bedroom near Verrazano bridge and ferry  32202051101
#
#            price service fee        country  minimum nights
# id
# 24444262  1200.0       $240   United States         -1223.0
# ...

# %% [markdown]
# ### Subsetting ###
#
# * Selecting just one column
# * Selecting several columns basis a list
# * Selecting rows basis a logical condition
# * Selecting based on string values
# * Selecting rows basis multiple conditions

# %% [markdown]
# selection is about picking one or specific group of columns, but all or selective rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102599 entries, 1001254 to 6094647
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   NAME                            102349 non-null  object
#  1   host id                         102599 non-null  int64
#  2   host_identity_verified          102310 non-null  object
#  3   host name                       102193 non-null  object
#  4   neighbourhood group             102570 non-null  object
#  5   neighbourhood                   102583 non-null  object
#  6   lat                             102591 non-null  float64
#  7   long                            102591 non-null  float64
#  8   country                         102067 non-null  object
#  9   country code                    102468 non-null  object
#  10  instant_bookable                102494 non-null  object
#  11  cancellation_policy             102523 non-null  object
# ...

# %%
df['NAME']
# Out:
# id
# 1001254                  Clean & quiet apt home by the park
# 1002102                               Skylit Midtown Castle
# 1002403                 THE VILLAGE OF HARLEM....NEW YORK !
# 1002755                                                 NaN
# 1003689    Entire Apt: Spacious Studio/Loft by central park
#                                  ...
# 6092437                          Spare room in Williamsburg
# 6092990                       Best Location near Columbia U
# 6093542                      Comfy, bright room in Brooklyn
# 6094094                    Big Studio-One Stop from Midtown
# 6094647                                585 sf Luxury Studio
# Name: NAME, Length: 102599, dtype: object

# %%
my_vars = ['NAME','price','service fee','country','minimum nights']
df[my_vars]
# Out:
#                                                      NAME   price service fee  \
# id
# 1001254                Clean & quiet apt home by the park   966.0       $193
# 1002102                             Skylit Midtown Castle   142.0        $28
# 1002403               THE VILLAGE OF HARLEM....NEW YORK !   620.0       $124
# 1002755                                               NaN   368.0        $74
# 1003689  Entire Apt: Spacious Studio/Loft by central park   204.0        $41
# ...                                                   ...     ...         ...
# 6092437                        Spare room in Williamsburg   844.0       $169
# 6092990                     Best Location near Columbia U   837.0       $167
# 6093542                    Comfy, bright room in Brooklyn   988.0       $198
# 6094094                  Big Studio-One Stop from Midtown   546.0       $109
# 6094647                              585 sf Luxury Studio  1032.0       $206
#
# ...

# %%
df[my_vars][df["price"] < 200].sort_values(by=columns_to_sort_on, ascending=[False, True]).head(10)
# Out:
#                                                        NAME  price  \
# id
# 2404730                 NYC - CLINTON HILL - FURNISHED ROOM  199.0
# 4718315                               Studio - Midtown East  199.0
# 5895819                    [203] 5 min WALK to Times Square  199.0
# 6560788                       Beautiful 1 Bedroom Apartment  199.0
# 7744367                     Beautiful 1BR  Garden Apt in BK  199.0
# 12171051         Large luxury private room in Williamsburg!  199.0
# 13373408                                        The Heights  199.0
# 15433487  Apartment-Styled space in Queens. 10Min from JFK.  199.0
# 16731945  Newly furnished & renovated rooms 5 min from nyc.  199.0
# 18102201                     Big Room in Quiet Neighborhood  199.0
#
#          service fee        country  minimum nights
# id
# 2404730         $40   United States             1.0
# 4718315         $40   United States             1.0
# 5895819         $40   United States             1.0
# ...

# %%
# convert service fee to float
df['service fee'] = df['service fee'].str.replace('$', '')
df['service fee'] = df['service fee'].str.replace(',', '')
df['service fee'] = df['service fee'].astype(float)

# %%
price_less_than_200 = df["price"] < 200
minimum_nights_greater_than_2 = df["minimum nights"] > 2
service_fee_less_than_50 = df["service fee"] < 30

df1 = df[price_less_than_200 & minimum_nights_greater_than_2 & service_fee_less_than_50][my_vars].sort_values(by=columns_to_sort_on, ascending=[False, True])

# %%
df1
# Out:
#                                                       NAME  price  \
# id
# 6509424                                        Noel Palace  147.0
# 7485890                Private Room in Bushwick - Brooklyn  147.0
# 10598653          Stylish 1BD in the heart of East Village  147.0
# 10786987  Peaceful Retreat with Garden in Brooklyn Heights  147.0
# 13819114          Clean and Comfortable Room near Columbia  147.0
# ...                                                    ...    ...
# 35945909    Stylish Apartment with office space Near SoHo!   50.0
# 38230774                   Lofted Room in East Village NYC   50.0
# 38696363                  Williamsburg 2 Bedroom Apartment   50.0
# 53977400                                    NYC Experience   50.0
# 27302414                            Williamsburg Apartment   50.0
#
#           service fee        country  minimum nights
# id
# 6509424          29.0  United States             3.0
# 7485890          29.0  United States             3.0
# ...

# %%
df1['minimum nights'].min()
# Out:
# 3.0

# %%
country_is_US = df['country code'] == 'US'
df[country_is_US]
# Out:
#                                                      NAME      host id  \
# id
# 1001254                Clean & quiet apt home by the park  80014485718
# 1002102                             Skylit Midtown Castle  52335172823
# 1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 1002755                                               NaN  85098326012
# 1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                   ...          ...
# 6092437                        Spare room in Williamsburg  12312296767
# 6092990                     Best Location near Columbia U  77864383453
# 6093542                    Comfy, bright room in Brooklyn  69050334417
# 6094094                  Big Studio-One Stop from Midtown  11160591270
# 6094647                              585 sf Luxury Studio  68170633372
#
#         host_identity_verified    host name neighbourhood group  \
# id
# ...

# %%
df['neighbourhood']
# Out:
# id
# 1001254             Kensington
# 1002102                Midtown
# 1002403                 Harlem
# 1002755           Clinton Hill
# 1003689            East Harlem
#                   ...
# 6092437           Williamsburg
# 6092990    Morningside Heights
# 6093542             Park Slope
# 6094094       Long Island City
# 6094647        Upper West Side
# Name: neighbourhood, Length: 102599, dtype: object

# %%
list_of_neighborhoods = ['Long Island City','Clinton Hill', 'Harlem']

# %%
in_neighborhood = df['neighbourhood'].isin(list_of_neighborhoods)

# %%
df[in_neighborhood]
# Out:
#                                         NAME      host id  \
# id
# 1002403  THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 1002755                                  NaN  85098326012
# 1018457                front room/double bed  69410526955
# 1019010  Spacious 1 bedroom in luxe building  80369762211
# 1020114                  back room/bunk beds  25066620900
# ...                                      ...          ...
# 6072002  Charming & Modern One Bedroom in BK  84262071868
# 6074764         1 bdr in the heart of Harlem  31012769204
# 6078078  Furnished Bedroom in 2 Bedroom apt.  43698780331
# 6086362               1 BR apartment sublet.  15723384490
# 6094094     Big Studio-One Stop from Midtown  11160591270
#
#         host_identity_verified    host name neighbourhood group  \
# id
# 1002403                    NaN        Elise           Manhattan
# 1002755            unconfirmed        Garry            Brooklyn
# ...
